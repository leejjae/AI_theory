# %% [raw]
# ---
# "title": "CNN"
# "author": "이정재"
# "date": "2024-05-03"
# ---

# %% [markdown]
# ## CNN(Convolutional Neural Network)

# %% [markdown]
# ### CNN's Structure

# %% [markdown]
# ![](https://images.squarespace-cdn.com/content/v1/5acbdd3a25bf024c12f4c8b4/1593967518672-RPGLD1X41M4OXWENZ0BN/CNN+Structure.jpg?format=2500w)\
# https://www.ml-science.com/convolutional-neural-networks

# %% [markdown]
# ### Conv filter

# %% [markdown]
# ![image.png](attachment:464bd226-6b67-41f3-a7f4-5ef9aadf33d1.png)

# %% [markdown]
# ![image.png](attachment:9c211531-ce8e-4a26-bb25-1d56eb643f92.png)

# %% [markdown]
# <img src="https://i.stack.imgur.com/2ezvr.gif" width="400" height="300">\
# https://stats.stackexchange.com/questions/296679/what-does-kernel-size-mean/296701

# %% [markdown]
# ![](https://jeiwan.net/images/convolution-filter-example.png)\
# https://jeiwan.net/posts/til-convolution-filters-are-weights/

# %% [markdown]
# ### Padding

# %% [markdown]
# ### Pooling
